# %%
# Imports and untilities from functions.ipynb

# %run functions.ipynb

all_results = sorted(glob.glob(path + "/*.json"))

all_data = sorted(glob.glob(path + "/*.csv"))

num = len(all_results)

# filter: don't include pre-study files
filtered_results = all_results[3:num]
filtered_data = all_data[3:num]

# remove P03
# filtered_results.pop(1)

display(filtered_results)
display(filtered_data)
# Out:
# ['../data/P02_2022-08-01.json',
#  '../data/P03_2022-08-02.json',
#  '../data/P04_2022-08-04.json',
#  '../data/P05_2022-08-05.json',
#  '../data/P06_2022-08-05.json',
#  '../data/P07_2022-08-06.json',
#  '../data/P08_2022-08-08.json',
#  '../data/P09_2022-08-08.json',
#  '../data/P10_2022-08-09.json',
#  '../data/P11_2022-08-09.json',
#  '../data/P12_2022-08-10.json',
#  '../data/P13_2022-08-10.json',
#  '../data/P14_2022-08-10.json',
#  '../data/P15_2022-08-11.json',
#  '../data/P16_2022-08-11.json',
#  '../data/P17_2022-08-12.json',
#  '../data/P18_2022-08-12.json',
#  '../data/P19_2022-08-15_merged.json',
#  '../data/P20_2022-08-18.json',
#  '../data/P21_2022-08-22.json',
#  '../data/P22_2022-08-23.json',
#  '../data/P23_2022-08-23.json']
# ['../data/P02_2022-08-01.csv',
#  '../data/P03_2022-08-02.csv',
#  '../data/P04_2022-08-04.csv',
#  '../data/P05_2022-08-05.csv',
#  '../data/P06_2022-08-05.csv',
#  '../data/P07_2022-08-06.csv',
#  '../data/P08_2022-08-08.csv',
#  '../data/P09_2022-08-08.csv',
#  '../data/P10_2022-08-09.csv',
#  '../data/P11_2022-08-09.csv',
#  '../data/P12_2022-08-10.csv',
#  '../data/P13_2022-08-10.csv',
#  '../data/P14_2022-08-10.csv',
#  '../data/P15_2022-08-11.csv',
#  '../data/P16_2022-08-11.csv',
#  '../data/P17_2022-08-12.csv',
#  '../data/P18_2022-08-12.csv',
#  '../data/P19_2022-08-15_merged.csv',
#  '../data/P20_2022-08-18.csv',
#  '../data/P21_2022-08-22.csv',
#  '../data/P22_2022-08-23.csv',
#  '../data/P23_2022-08-23.csv']

# %%
results = []

totalLength = 0
resultlength = 0

for filename in filtered_results:
    df2 = pd.read_json(filename, lines=True)
    df2.pop('level')
    fn = os.path.basename(filename).split(".")[0]    
    df2["file"] = fn
    resultlength += len(df2)
    results.append(df2)


results_complete = pd.concat(results, ignore_index=True)

results_complete["StartDate_DT"] = pd.to_datetime(results_complete["StartDate"], format=timeFormat)
results_complete["CommitResultDate_DT"] = pd.to_datetime(results_complete["CommitResultDate"], format=timeFormat)
results_complete["EndInteractionDate_DT"] = pd.to_datetime(results_complete["EndInteractionDate"], format=timeFormat)

display (results_complete)
# Out:
#       BlockId          CommitResultDate          Condition  \
# 0          -4  2022-08-01T14:01:37.953Z  Combined Feedback
# 1          -4  2022-08-01T14:02:26.995Z  Combined Feedback
# 2          -3  2022-08-01T14:03:44.338Z    Visual Feedback
# 3          -3  2022-08-01T14:04:34.107Z    Visual Feedback
# 4          -2  2022-08-01T14:07:33.355Z   Tactile Feedback
# ...       ...                       ...                ...
# 2019        3  2022-08-23T11:27:13.692Z        No Feedback
# 2020        3  2022-08-23T11:27:49.516Z        No Feedback
# 2021        3  2022-08-23T11:28:51.795Z        No Feedback
# 2022        3  2022-08-23T11:29:32.908Z        No Feedback
# 2023        3  2022-08-23T11:30:05.548Z        No Feedback
#
#             EndInteractionDate  ExpectedResultLayer  ExpectedResultNumber  \
# 0     2022-08-01T14:01:30.874Z                    3                   176
# 1     2022-08-01T14:02:22.682Z                    7                   158
# 2     2022-08-01T14:03:39.613Z                    2                   161
# 3     2022-08-01T14:04:29.378Z                    4                   150
# 4     2022-08-01T14:07:23.779Z                    6                   160
# ...                        ...                  ...                   ...
# 2019  2022-08-23T11:27:09.628Z                    7                   159
# 2020  2022-08-23T11:27:45.172Z                    5                   157
# 2021  2022-08-23T11:28:46.148Z                    6                   148
# 2022  2022-08-23T11:29:29.764Z                    1                   152
# 2023  2022-08-23T11:30:01.812Z                    7                   169
#
#                  LayerNumberConfiguration  ProbandId  ProvidedResultLayer  \
# 0     [131, 144, 176, 153, 147, 135, 114]          2                    2
# 1     [149, 118, 145, 137, 147, 146, 158]          2                    4
# 2     [150, 161, 134, 151, 128, 149, 127]          2                    2
# 3     [132, 144, 148, 150, 149, 147, 130]          2                    4
# 4     [139, 144, 128, 136, 156, 160, 137]          2                    3
# ...                                   ...        ...                  ...
# 2019  [153, 122, 128, 144, 140, 154, 159]         23                    7
# 2020  [146, 142, 133, 156, 157, 128, 138]         23                    5
# 2021  [139, 140, 143, 147, 142, 148, 141]         23                    6
# 2022  [152, 139, 138, 134, 145, 144, 148]         23                    1
# 2023  [149, 122, 137, 130, 150, 143, 169]         23                    7
#
#       ProvidedResultNumber                 StartDate  Training  TrialId  \
# 0                      153  2022-08-01T13:59:15.117Z      True        0
# 1                      147  2022-08-01T14:01:37.954Z      True        1
# 2                      161  2022-08-01T14:02:33.306Z      True        0
# 3                      150  2022-08-01T14:03:44.339Z      True        1
# 4                      160  2022-08-01T14:05:08.405Z      True        0
# ...                    ...                       ...       ...      ...
# 2019                   159  2022-08-23T11:26:32.356Z     False       16
# 2020                   157  2022-08-23T11:27:13.693Z     False       17
# 2021                   148  2022-08-23T11:27:49.516Z     False       18
# 2022                   152  2022-08-23T11:28:51.796Z     False       19
# 2023                   169  2022-08-23T11:29:32.908Z     False       20
#
#                 file            StartDate_DT     CommitResultDate_DT  \
# 0     P02_2022-08-01 2022-08-01 13:59:15.117 2022-08-01 14:01:37.953
# 1     P02_2022-08-01 2022-08-01 14:01:37.954 2022-08-01 14:02:26.995
# 2     P02_2022-08-01 2022-08-01 14:02:33.306 2022-08-01 14:03:44.338
# 3     P02_2022-08-01 2022-08-01 14:03:44.339 2022-08-01 14:04:34.107
# 4     P02_2022-08-01 2022-08-01 14:05:08.405 2022-08-01 14:07:33.355
# ...              ...                     ...                     ...
# 2019  P23_2022-08-23 2022-08-23 11:26:32.356 2022-08-23 11:27:13.692
# 2020  P23_2022-08-23 2022-08-23 11:27:13.693 2022-08-23 11:27:49.516
# 2021  P23_2022-08-23 2022-08-23 11:27:49.516 2022-08-23 11:28:51.795
# 2022  P23_2022-08-23 2022-08-23 11:28:51.796 2022-08-23 11:29:32.908
# 2023  P23_2022-08-23 2022-08-23 11:29:32.908 2022-08-23 11:30:05.548
#
#        EndInteractionDate_DT
# 0    2022-08-01 14:01:30.874
# 1    2022-08-01 14:02:22.682
# 2    2022-08-01 14:03:39.613
# 3    2022-08-01 14:04:29.378
# 4    2022-08-01 14:07:23.779
# ...                      ...
# 2019 2022-08-23 11:27:09.628
# 2020 2022-08-23 11:27:45.172
# 2021 2022-08-23 11:28:46.148
# 2022 2022-08-23 11:29:29.764
# 2023 2022-08-23 11:30:01.812
#
# [2024 rows x 17 columns]

# %%
study = []
totalLength = 0

for filename in filtered_data:
    df = pd.read_csv(filename, sep=";")
    fn = os.path.basename(filename).split(".")[0] 

    df["Block"] = pd.to_numeric(df["Block"])
    df["Trial"] = pd.to_numeric(df["Trial"])

    df["file"] = fn
    totalLength += len(df)
    study.append(df)
    
print("totallines: " + str(totalLength))

data_complete = pd.concat(study, ignore_index=True)

data_complete['Date'] = pd.to_datetime(data_complete["Date"], format=timeFormat)
# sort by date (necessary as some log messages are written in correct time order)
data_complete = data_complete.sort_values(by=['Date'], ignore_index=True)

data_complete['SubStateChange'] = data_complete['ProgramSubState'].diff()
data_complete['StateChange'] = data_complete['ProgramState'].diff()

data_complete['TrialChange'] = data_complete['Trial'].diff()

# compute significant state changes
num_trials = data_complete[data_complete['TrialChange'] != 0]

display(num_trials)

data_complete['StateChangeMarker']  = '-'
mask = (data_complete['StateChange'] == 1) & (data_complete['ProgramState'] == 4)

data_complete.loc[mask, 'StateChangeMarker'] = 'START_BLOCK | START_EXPERIMENT'

mask = (data_complete['StateChange'] == -1) & (data_complete['ProgramState'] == 3)
data_complete.loc[mask, 'StateChangeMarker'] = 'START_BLOCK | START_TRAINING'


data_complete.loc[0, 'StateChangeMarker'] = 'START_BLOCK | START_TRAINING'
# .loc[pd.isna(data_complete['StateChangeMarker'])]] = 

mask = (data_complete['SubStateChange'] == -2) & (data_complete['StateChange'] == 0)
data_complete.loc[mask, 'StateChangeMarker'] = 'START_BLOCK'

mask = (data_complete['SubStateChange'] != 0) & (data_complete['ProgramSubState'] == 1)
data_complete.loc[mask, 'StateChangeMarker'] = 'START_INTERACTION'

mask = (data_complete['SubStateChange'] == 1) & (data_complete['ProgramSubState'] == 2)
data_complete.loc[mask, 'StateChangeMarker'] = 'START_INPUT'

allProbands = data_complete['ProbandId'].drop_duplicates()

count_input = data_complete['StateChangeMarker'].eq('START_INPUT').sum()
count_interaction =  data_complete['StateChangeMarker'].eq('START_INTERACTION').sum()

count_block = data_complete['StateChangeMarker'].str.contains('START_BLOCK').sum()

count_training = data_complete['StateChangeMarker'].str.contains('START_TRAINING').sum()
count_experiment = data_complete['StateChangeMarker'].str.contains('START_EXPERIMENT').sum()

# assert correct numbers: 
display(f'Number of Participants: {len(allProbands)}')

# should be: 92 x numProbands
display(f'Number of Input-Markers: {count_input} [{len(allProbands)} x ((4 x 2) + (4 x 21))]')

# should be: 92 x numProbands
display(f'Number of Interaction-Markers: {count_interaction} [{len(allProbands)} x ((4 x 2) + (4 x 21))]')

# should be 8 x numProbands
display(f'Number of Blocks: {count_block} [{len(allProbands)} x (4 + 4)]')

# should be numProbands
display(f'Number of Training: {count_training}')

# should be numProbands
display(f'Number of Experiment: {count_experiment}')

data_complete.drop(df.columns[41], axis=1, inplace=True)

display (data_complete)
# Out:
# totallines: 3371632
#                            Date  ProbandId  Block  Trial  TrialNumber  \
# 0       2022-08-01 13:58:38.416          2     -4      0           -8
# 5982    2022-08-01 14:01:37.965          2     -4      1           -7
# 7616    2022-08-01 14:02:27.000          2     -3      0           -6
# 10193   2022-08-01 14:03:44.342          2     -3      1           -5
# 11852   2022-08-01 14:04:34.119          2     -2      0           -4
# ...                         ...        ...    ...    ...          ...
# 3364529 2022-08-23 11:26:32.384         23      3     16           79
# 3365906 2022-08-23 11:27:13.704         23      3     17           80
# 3367100 2022-08-23 11:27:49.534         23      3     18           81
# 3369174 2022-08-23 11:28:51.802         23      3     19           82
# 3370545 2022-08-23 11:29:32.930         23      3     20           83
#
#                  Condition  ResultNumber  ResultLayer  ProgramState  \
# 0        Combined Feedback           176            3             3
# 5982     Combined Feedback           158            7             3
# 7616       Visual Feedback           161            2             3
# 10193      Visual Feedback           150            4             3
# 11852     Tactile Feedback           160            6             3
# ...                    ...           ...          ...           ...
# 3364529        No Feedback           159            7             4
# 3365906        No Feedback           157            5             4
# 3367100        No Feedback           148            6             4
# 3369174        No Feedback           152            1             4
# 3370545        No Feedback           169            7             4
#
#          ProgramSubState  ...  Layer03 Layer04 Layer05 Layer06 Layer07  \
# 0                      0  ...      176     153     147     135     114
# 5982                   1  ...      145     137     147     146     158
# 7616                   0  ...      134     151     128     149     127
# 10193                  1  ...      148     150     149     147     130
# 11852                  0  ...      128     136     156     160     137
# ...                  ...  ...      ...     ...     ...     ...     ...
# 3364529                1  ...      128     144     140     154     159
# 3365906                1  ...      133     156     157     128     138
# 3367100                1  ...      143     147     142     148     141
# 3369174                1  ...      138     134     145     144     148
# 3370545                1  ...      137     130     150     143     169
#
#                    file  Unnamed: 41 SubStateChange StateChange TrialChange
# 0        P02_2022-08-01          NaN            NaN         NaN         NaN
# 5982     P02_2022-08-01          NaN           -1.0         0.0         1.0
# 7616     P02_2022-08-01          NaN           -2.0         0.0        -1.0
# 10193    P02_2022-08-01          NaN           -1.0         0.0         1.0
# 11852    P02_2022-08-01          NaN           -2.0         0.0        -1.0
# ...                 ...          ...            ...         ...         ...
# 3364529  P23_2022-08-23          NaN           -1.0         0.0         1.0
# 3365906  P23_2022-08-23          NaN           -1.0         0.0         1.0
# 3367100  P23_2022-08-23          NaN           -1.0         0.0         1.0
# 3369174  P23_2022-08-23          NaN           -1.0         0.0         1.0
# 3370545  P23_2022-08-23          NaN           -1.0         0.0         1.0
#
# [2024 rows x 46 columns]
# 'Number of Participants: 22'
# 'Number of Input-Markers: 2024 [22 x ((4 x 2) + (4 x 21))]'
# 'Number of Interaction-Markers: 2024 [22 x ((4 x 2) + (4 x 21))]'
# 'Number of Blocks: 176 [22 x (4 + 4)]'
# 'Number of Training: 22'
# 'Number of Experiment: 22'
#                            Date  ProbandId  Block  Trial  TrialNumber  \
# 0       2022-08-01 13:58:38.416          2     -4      0           -8
# 1       2022-08-01 13:58:38.448          2     -4      0           -8
# 2       2022-08-01 13:58:38.477          2     -4      0           -8
# 3       2022-08-01 13:58:38.508          2     -4      0           -8
# 4       2022-08-01 13:58:38.541          2     -4      0           -8
# ...                         ...        ...    ...    ...          ...
# 3371627 2022-08-23 11:30:05.409         23      3     20           83
# 3371628 2022-08-23 11:30:05.440         23      3     20           83
# 3371629 2022-08-23 11:30:05.472         23      3     20           83
# 3371630 2022-08-23 11:30:05.503         23      3     20           83
# 3371631 2022-08-23 11:30:05.518         23      3     20           83
#
#                  Condition  ResultNumber  ResultLayer  ProgramState  \
# 0        Combined Feedback           176            3             3
# 1        Combined Feedback           176            3             3
# 2        Combined Feedback           176            3             3
# 3        Combined Feedback           176            3             3
# 4        Combined Feedback           176            3             3
# ...                    ...           ...          ...           ...
# 3371627        No Feedback           169            7             4
# 3371628        No Feedback           169            7             4
# 3371629        No Feedback           169            7             4
# 3371630        No Feedback           169            7             4
# 3371631        No Feedback           169            7             4
#
#          ProgramSubState  ...  Layer03 Layer04 Layer05 Layer06 Layer07  \
# 0                      0  ...      176     153     147     135     114
# 1                      0  ...      176     153     147     135     114
# 2                      0  ...      176     153     147     135     114
# 3                      0  ...      176     153     147     135     114
# 4                      0  ...      176     153     147     135     114
# ...                  ...  ...      ...     ...     ...     ...     ...
# 3371627                2  ...      137     130     150     143     169
# 3371628                2  ...      137     130     150     143     169
# 3371629                2  ...      137     130     150     143     169
# 3371630                2  ...      137     130     150     143     169
# 3371631                2  ...      137     130     150     143     169
#
#                    file  SubStateChange StateChange TrialChange  \
# 0        P02_2022-08-01             NaN         NaN         NaN
# 1        P02_2022-08-01             0.0         0.0         0.0
# 2        P02_2022-08-01             0.0         0.0         0.0
# 3        P02_2022-08-01             0.0         0.0         0.0
# 4        P02_2022-08-01             0.0         0.0         0.0
# ...                 ...             ...         ...         ...
# 3371627  P23_2022-08-23             0.0         0.0         0.0
# 3371628  P23_2022-08-23             0.0         0.0         0.0
# 3371629  P23_2022-08-23             0.0         0.0         0.0
# 3371630  P23_2022-08-23             0.0         0.0         0.0
# 3371631  P23_2022-08-23             0.0         0.0         0.0
#
#                     StateChangeMarker
# 0        START_BLOCK | START_TRAINING
# 1                                   -
# 2                                   -
# 3                                   -
# 4                                   -
# ...                               ...
# 3371627                             -
# 3371628                             -
# 3371629                             -
# 3371630                             -
# 3371631                             -
#
# [3371632 rows x 46 columns]

# %% [markdown]
# # remove leading and trailing idle times in interaction phase

# %%
grouped = data_complete[data_complete['Block'] >= 0].groupby(['ProbandId', 'TrialNumber'])

results_complete['TrialNumber'] = 0
results_complete['CleanedUpInteractionStart_DT'] = results_complete['StartDate_DT']
results_complete['CleanedUpInteractionEnd_DT'] = results_complete['EndInteractionDate_DT']

for name, group in grouped:

   p = name[0]
   t = name[1]

   interactionStart = group[group['PosZ'] != '-'].head(1)
   interactionEnd = group[group['PosZ'] != '-'].tail(1)

   date_start = interactionStart['Date']
   date_stop = interactionEnd['Date']

   b = interactionStart['Block'].values[0]
   tId = interactionStart['Trial'].values[0]

   data_complete.loc[date_start.index[0], 'StateChangeMarker'] = 'INTERACTION_START_CLEANED'
   data_complete.loc[date_stop.index[0], 'StateChangeMarker'] = 'INTERACTION_END_CLEANED'

   associatedResult = results_complete[(results_complete['ProbandId'] == p) & (results_complete['BlockId'] == b) & (results_complete['TrialId'] == tId)]
   
   # if participant data is not existing in both data and results
   if len(associatedResult) <= 0:
      continue
   
   idx = associatedResult.index[0]
   
   results_complete.loc[idx, 'TrialNumber'] = t
   results_complete.loc[idx, 'CleanedUpInteractionStart_DT'] = date_start.values[0]
   results_complete.loc[idx, 'CleanedUpInteractionEnd_DT'] = date_stop.values[0]
   

results_complete['ResultNumberDifference'] = results_complete['ProvidedResultNumber'] - results_complete['ExpectedResultNumber']
results_complete['ResultLayerDifference'] = results_complete['ProvidedResultLayer'] - results_complete['ExpectedResultLayer']

results_complete['ResultLayerCorrect'] = results_complete['ResultLayerDifference'] == 0
results_complete['ResultNumberCorrect'] = results_complete['ResultNumberDifference'] == 0

results_complete['CommitResultDate_DT'] = results_complete['CommitResultDate_DT'].apply(pd.to_datetime)
results_complete['EndInteractionDate_DT'] = results_complete['EndInteractionDate_DT'].apply(pd.to_datetime)
results_complete['StartDate_DT'] = results_complete['StartDate_DT'].apply(pd.to_datetime)

# compute duration of interaction phase
results_complete['DurationMS'] = (results_complete['EndInteractionDate_DT'] - results_complete['StartDate_DT']).dt.total_seconds()

# compute duration of interaction phase
results_complete['DurationMS_Cleaned'] = (results_complete['CleanedUpInteractionEnd_DT'] - results_complete['CleanedUpInteractionStart_DT']).dt.total_seconds()

# need to compute a grouping index for conditions
results_complete['countCondition'] = results_complete.groupby(['Condition']).cumcount()

display(results_complete)
display(data_complete)

saveData(data_complete)
saveResults(results_complete)
# Out:
#       BlockId          CommitResultDate          Condition  \
# 0          -4  2022-08-01T14:01:37.953Z  Combined Feedback
# 1          -4  2022-08-01T14:02:26.995Z  Combined Feedback
# 2          -3  2022-08-01T14:03:44.338Z    Visual Feedback
# 3          -3  2022-08-01T14:04:34.107Z    Visual Feedback
# 4          -2  2022-08-01T14:07:33.355Z   Tactile Feedback
# ...       ...                       ...                ...
# 2019        3  2022-08-23T11:27:13.692Z        No Feedback
# 2020        3  2022-08-23T11:27:49.516Z        No Feedback
# 2021        3  2022-08-23T11:28:51.795Z        No Feedback
# 2022        3  2022-08-23T11:29:32.908Z        No Feedback
# 2023        3  2022-08-23T11:30:05.548Z        No Feedback
#
#             EndInteractionDate  ExpectedResultLayer  ExpectedResultNumber  \
# 0     2022-08-01T14:01:30.874Z                    3                   176
# 1     2022-08-01T14:02:22.682Z                    7                   158
# 2     2022-08-01T14:03:39.613Z                    2                   161
# 3     2022-08-01T14:04:29.378Z                    4                   150
# 4     2022-08-01T14:07:23.779Z                    6                   160
# ...                        ...                  ...                   ...
# 2019  2022-08-23T11:27:09.628Z                    7                   159
# 2020  2022-08-23T11:27:45.172Z                    5                   157
# 2021  2022-08-23T11:28:46.148Z                    6                   148
# 2022  2022-08-23T11:29:29.764Z                    1                   152
# 2023  2022-08-23T11:30:01.812Z                    7                   169
#
#                  LayerNumberConfiguration  ProbandId  ProvidedResultLayer  \
# 0     [131, 144, 176, 153, 147, 135, 114]          2                    2
# 1     [149, 118, 145, 137, 147, 146, 158]          2                    4
# 2     [150, 161, 134, 151, 128, 149, 127]          2                    2
# 3     [132, 144, 148, 150, 149, 147, 130]          2                    4
# 4     [139, 144, 128, 136, 156, 160, 137]          2                    3
# ...                                   ...        ...                  ...
# 2019  [153, 122, 128, 144, 140, 154, 159]         23                    7
# 2020  [146, 142, 133, 156, 157, 128, 138]         23                    5
# 2021  [139, 140, 143, 147, 142, 148, 141]         23                    6
# 2022  [152, 139, 138, 134, 145, 144, 148]         23                    1
# 2023  [149, 122, 137, 130, 150, 143, 169]         23                    7
#
#       ProvidedResultNumber  ... TrialNumber  CleanedUpInteractionStart_DT  \
# 0                      153  ...           0       2022-08-01 13:59:15.117
# 1                      147  ...           0       2022-08-01 14:01:37.954
# 2                      161  ...           0       2022-08-01 14:02:33.306
# 3                      150  ...           0       2022-08-01 14:03:44.339
# 4                      160  ...           0       2022-08-01 14:05:08.405
# ...                    ...  ...         ...                           ...
# 2019                   159  ...          79       2022-08-23 11:26:33.878
# 2020                   157  ...          80       2022-08-23 11:27:15.467
# 2021                   148  ...          81       2022-08-23 11:27:50.891
# 2022                   152  ...          82       2022-08-23 11:28:54.105
# 2023                   169  ...          83       2022-08-23 11:29:34.429
#
#       CleanedUpInteractionEnd_DT ResultNumberDifference ResultLayerDifference  \
# 0        2022-08-01 14:01:30.874                    -23                    -1
# 1        2022-08-01 14:02:22.682                    -11                    -3
# 2        2022-08-01 14:03:39.613                      0                     0
# 3        2022-08-01 14:04:29.378                      0                     0
# 4        2022-08-01 14:07:23.779                      0                    -3
# ...                          ...                    ...                   ...
# 2019     2022-08-23 11:27:08.564                      0                     0
# 2020     2022-08-23 11:27:44.655                      0                     0
# 2021     2022-08-23 11:28:45.618                      0                     0
# 2022     2022-08-23 11:29:28.940                      0                     0
# 2023     2022-08-23 11:30:00.879                      0                     0
#
#      ResultLayerCorrect ResultNumberCorrect  DurationMS DurationMS_Cleaned  \
# 0                 False               False     135.757            135.757
# 1                 False               False      44.728             44.728
# 2                  True                True      66.307             66.307
# 3                  True                True      45.039             45.039
# 4                 False                True     135.374            135.374
# ...                 ...                 ...         ...                ...
# 2019               True                True      37.272             34.686
# 2020               True                True      31.479             29.188
# 2021               True                True      56.632             54.727
# 2022               True                True      37.968             34.835
# 2023               True                True      28.904             26.450
#
#      countCondition
# 0                 0
# 1                 1
# 2                 0
# 3                 1
# 4                 0
# ...             ...
# 2019            501
# 2020            502
# 2021            503
# 2022            504
# 2023            505
#
# [2024 rows x 27 columns]
#                            Date  ProbandId  Block  Trial  TrialNumber  \
# 0       2022-08-01 13:58:38.416          2     -4      0           -8
# 1       2022-08-01 13:58:38.448          2     -4      0           -8
# 2       2022-08-01 13:58:38.477          2     -4      0           -8
# 3       2022-08-01 13:58:38.508          2     -4      0           -8
# 4       2022-08-01 13:58:38.541          2     -4      0           -8
# ...                         ...        ...    ...    ...          ...
# 3371627 2022-08-23 11:30:05.409         23      3     20           83
# 3371628 2022-08-23 11:30:05.440         23      3     20           83
# 3371629 2022-08-23 11:30:05.472         23      3     20           83
# 3371630 2022-08-23 11:30:05.503         23      3     20           83
# 3371631 2022-08-23 11:30:05.518         23      3     20           83
#
#                  Condition  ResultNumber  ResultLayer  ProgramState  \
# 0        Combined Feedback           176            3             3
# 1        Combined Feedback           176            3             3
# 2        Combined Feedback           176            3             3
# 3        Combined Feedback           176            3             3
# 4        Combined Feedback           176            3             3
# ...                    ...           ...          ...           ...
# 3371627        No Feedback           169            7             4
# 3371628        No Feedback           169            7             4
# 3371629        No Feedback           169            7             4
# 3371630        No Feedback           169            7             4
# 3371631        No Feedback           169            7             4
#
#          ProgramSubState  ...  Layer03 Layer04 Layer05 Layer06 Layer07  \
# 0                      0  ...      176     153     147     135     114
# 1                      0  ...      176     153     147     135     114
# 2                      0  ...      176     153     147     135     114
# 3                      0  ...      176     153     147     135     114
# 4                      0  ...      176     153     147     135     114
# ...                  ...  ...      ...     ...     ...     ...     ...
# 3371627                2  ...      137     130     150     143     169
# 3371628                2  ...      137     130     150     143     169
# 3371629                2  ...      137     130     150     143     169
# 3371630                2  ...      137     130     150     143     169
# 3371631                2  ...      137     130     150     143     169
#
#                    file  SubStateChange StateChange TrialChange  \
# 0        P02_2022-08-01             NaN         NaN         NaN
# 1        P02_2022-08-01             0.0         0.0         0.0
# 2        P02_2022-08-01             0.0         0.0         0.0
# 3        P02_2022-08-01             0.0         0.0         0.0
# 4        P02_2022-08-01             0.0         0.0         0.0
# ...                 ...             ...         ...         ...
# 3371627  P23_2022-08-23             0.0         0.0         0.0
# 3371628  P23_2022-08-23             0.0         0.0         0.0
# 3371629  P23_2022-08-23             0.0         0.0         0.0
# 3371630  P23_2022-08-23             0.0         0.0         0.0
# 3371631  P23_2022-08-23             0.0         0.0         0.0
#
#                     StateChangeMarker
# 0        START_BLOCK | START_TRAINING
# 1                                   -
# 2                                   -
# 3                                   -
# 4                                   -
# ...                               ...
# 3371627                             -
# 3371628                             -
# 3371629                             -
# 3371630                             -
# 3371631                             -
#
# [3371632 rows x 46 columns]

# %%
data_complete['diff_NumberDisplay'] = data_complete['DataNumberDisplayed'].diff()
data_complete.loc[0, 'diff_NumberDisplay'] = 0.0

data_complete['LayerChange'] = data_complete['Layer'].replace('-', -1).astype(float).diff()
data_complete.loc[0, 'LayerChange'] = -1

show = data_complete[data_complete['diff_NumberDisplay'] > 0.0]

subStateChange = data_complete[data_complete['SubStateChange'] != 0]
hide = data_complete[data_complete['diff_NumberDisplay'] < 0.0]

# hide = []

for idx, item in show.iterrows():
    nextHide = hide[hide['Date'] > item['Date']].head(1)
    nextStateChange = subStateChange[subStateChange['Date'] > item['Date']].head(1)

    show.at[idx, 'nextStateChangeIdx'] = int(nextStateChange.index[0])
    show.at[idx, 'nextStateChangeDate'] = nextStateChange['Date'].values[0]
    show.at[idx, 'nextHideIdx'] = int(nextHide.index[0])
    show.at[idx, 'nextHideDate'] = nextHide['Date'].values[0]

show = show.rename_axis('show_index').reset_index()
show['hide_index'] = np.minimum(show['nextStateChangeIdx'], show['nextHideIdx'])
show['hide_date'] = np.minimum(show['nextStateChangeDate'], show['nextHideDate'])

display(show)

df_NumberDisplayed = pd.DataFrame()
df_NumberDisplayed['ShowIndex'] = show['show_index']
df_NumberDisplayed['ShowDate'] = pd.to_datetime(show['Date'])
df_NumberDisplayed['HideIndex'] = show['hide_index']
df_NumberDisplayed['HideDate'] = show['hide_date']
df_NumberDisplayed['Condition'] = show['Condition']
df_NumberDisplayed['TrialNumber'] = show['TrialNumber']
df_NumberDisplayed['Layer'] = show['Layer']
df_NumberDisplayed['ResultLayer'] = show['ResultLayer']
df_NumberDisplayed['BlockId'] = show['Block']
df_NumberDisplayed['ProbandId'] = show['ProbandId']

# df_NumberDisplayed = df_NumberDisplayed[:10]

lastLayerChange = list(map(getLastLayerChange, df_NumberDisplayed['ShowIndex']))

df_layerChange = pd.DataFrame(lastLayerChange, columns=['LastLayerChangeDate','LastLayerChangeIndex'])
df_NumberDisplayed = pd.concat([df_NumberDisplayed, df_layerChange], axis = 1)

df_NumberDisplayed['LastLayerChangeDate'] = pd.to_datetime( df_NumberDisplayed['LastLayerChangeDate'])

df_NumberDisplayed['Duration_ShowNumber'] = (df_NumberDisplayed['HideDate'] - df_NumberDisplayed['ShowDate']).dt.total_seconds()
df_NumberDisplayed['Duration_FindCenter'] = (df_NumberDisplayed['ShowDate'] - df_NumberDisplayed['LastLayerChangeDate']).dt.total_seconds()

df_NumberDisplayed_experiment = df_NumberDisplayed[df_NumberDisplayed['BlockId'] >= 0]

df_NumberDisplayed.to_csv(rf'{export_data}numberDisplayed_all.csv', sep= ";")
df_NumberDisplayed_experiment.to_csv(rf'{export_data}numberDisplayed_experiment.csv', sep= ";")


display(df_NumberDisplayed.describe()['Duration_ShowNumber'])
# Out:
# /var/folders/94/jmc3f73x53bbbvrrms8z445m0000gn/T/ipykernel_68514/2032996742.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   show.at[idx, 'nextStateChangeIdx'] = int(nextStateChange.index[0])
# /var/folders/94/jmc3f73x53bbbvrrms8z445m0000gn/T/ipykernel_68514/2032996742.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   show.at[idx, 'nextStateChangeDate'] = nextStateChange['Date'].values[0]
# /var/folders/94/jmc3f73x53bbbvrrms8z445m0000gn/T/ipykernel_68514/2032996742.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   show.at[idx, 'nextHideIdx'] = int(nextHide.index[0])
# /var/folders/94/jmc3f73x53bbbvrrms8z445m0000gn/T/ipykernel_68514/2032996742.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   show.at[idx, 'nextHideDate'] = nextHide['Date'].values[0]
#        show_index                    Date  ProbandId  Block  Trial  \
# 0            1970 2022-08-01 13:59:37.537          2     -4      0
# 1            2328 2022-08-01 13:59:48.273          2     -4      0
# 2            2362 2022-08-01 13:59:49.338          2     -4      0
# 3            2449 2022-08-01 13:59:51.920          2     -4      0
# 4            3012 2022-08-01 14:00:08.825          2     -4      0
# ...           ...                     ...        ...    ...    ...
# 18566     3370972 2022-08-23 11:29:45.766         23      3     20
# 18567     3371074 2022-08-23 11:29:48.804         23      3     20
# 18568     3371151 2022-08-23 11:29:51.125         23      3     20
# 18569     3371202 2022-08-23 11:29:52.646         23      3     20
# 18570     3371420 2022-08-23 11:29:59.195         23      3     20
#
#        TrialNumber          Condition  ResultNumber  ResultLayer  \
# 0               -8  Combined Feedback           176            3
# 1               -8  Combined Feedback           176            3
# 2               -8  Combined Feedback           176            3
# 3               -8  Combined Feedback           176            3
# 4               -8  Combined Feedback           176            3
# ...            ...                ...           ...          ...
# 18566           83        No Feedback           169            7
# 18567           83        No Feedback           169            7
# 18568           83        No Feedback           169            7
# 18569           83        No Feedback           169            7
# 18570           83        No Feedback           169            7
#
#        ProgramState  ...  TrialChange  StateChangeMarker diff_NumberDisplay  \
# 0                 3  ...          0.0                  -              145.0
# 1                 3  ...          0.0                  -              132.0
# 2                 3  ...          0.0                  -              145.0
# 3                 3  ...          0.0                  -              177.0
# 4                 3  ...          0.0                  -              145.0
# ...             ...  ...          ...                ...                ...
# 18566             4  ...          0.0                  -              131.0
# 18567             4  ...          0.0                  -              151.0
# 18568             4  ...          0.0                  -              144.0
# 18569             4  ...          0.0                  -              144.0
# 18570             4  ...          0.0                  -              170.0
#
#       LayerChange nextStateChangeIdx     nextStateChangeDate nextHideIdx  \
# 0             0.0             5747.0 2022-08-01 14:01:30.883      2017.0
# 1             0.0             5747.0 2022-08-01 14:01:30.883      2330.0
# 2             0.0             5747.0 2022-08-01 14:01:30.883      2415.0
# 3             0.0             5747.0 2022-08-01 14:01:30.883      2450.0
# 4             0.0             5747.0 2022-08-01 14:01:30.883      3022.0
# ...           ...                ...                     ...         ...
# 18566         0.0          3371508.0 2022-08-23 11:30:01.828   3370999.0
# 18567         0.0          3371508.0 2022-08-23 11:30:01.828   3371093.0
# 18568         0.0          3371508.0 2022-08-23 11:30:01.828   3371152.0
# 18569         0.0          3371508.0 2022-08-23 11:30:01.828   3371249.0
# 18570         0.0          3371508.0 2022-08-23 11:30:01.828   3371466.0
#
#                  nextHideDate hide_index               hide_date
# 0     2022-08-01 13:59:38.947     2017.0 2022-08-01 13:59:38.947
# 1     2022-08-01 13:59:48.336     2330.0 2022-08-01 13:59:48.336
# 2     2022-08-01 13:59:50.891     2415.0 2022-08-01 13:59:50.891
# 3     2022-08-01 13:59:51.953     2450.0 2022-08-01 13:59:51.953
# 4     2022-08-01 14:00:09.123     3022.0 2022-08-01 14:00:09.123
# ...                       ...        ...                     ...
# 18566 2022-08-23 11:29:46.561  3370999.0 2022-08-23 11:29:46.561
# 18567 2022-08-23 11:29:49.380  3371093.0 2022-08-23 11:29:49.380
# 18568 2022-08-23 11:29:51.155  3371152.0 2022-08-23 11:29:51.155
# 18569 2022-08-23 11:29:54.062  3371249.0 2022-08-23 11:29:54.062
# 18570 2022-08-23 11:30:00.568  3371466.0 2022-08-23 11:30:00.568
#
# [18571 rows x 55 columns]
# count    18571.000000
# mean         0.911041
# min          0.009000
# 25%          0.419000
# 50%          0.886000
# 75%          1.159000
# max         16.107000
# std          0.700946
# Name: Duration_ShowNumber, dtype: float64
